# %%
df.rename(columns= {'timeVectRelMinutes': 'datetime'}, inplace=True)
df['datetime'] = pd.to_datetime(df['datetime'], unit='m', origin='2020-01-30')

# %%
df['index'] = df.index

# %%
df.loc[14300:14500].plot(x='index', y =['engMdoPower_1_', 'engMdoPower_3_', 'thrusterAndPropulsion', 'battery_0__actualPower'])
# Out:
# <AxesSubplot:xlabel='index'>

# %%
df.loc[25350:25750].plot(x='index', y =['engMdoPower_1_', 'engMdoPower_3_', 'thrusterAndPropulsion',
                                        'battery_0__actualPower'])
# Out:
# <AxesSubplot:xlabel='index'>

# %%
df.loc[51600:52000].plot(x='index', y =['engMdoPower_1_', 'engMdoPower_3_', 'thrusterAndPropulsion', 'battery_0__actualPower'])
# Out:
# <AxesSubplot:xlabel='index'>

# %%
df.loc[58700:58900].plot(x='index', y =['engMdoPower_1_', 'engMdoPower_3_', 'thrusterAndPropulsion', 'battery_0__actualPower'])
# Out:
# <AxesSubplot:xlabel='index'>

# %%
df.loc[61000:61600].plot(x='index', y =['engMdoPower_1_', 'engMdoPower_3_', 'thrusterAndPropulsion', 'battery_0__actualPower'])
# Out:
# <AxesSubplot:xlabel='index'>

# %%
df.loc[61260:61350].plot(x='index', y =['engMdoPower_1_', 'engMdoPower_3_', 'thrusterAndPropulsion', 'battery_0__actualPower'])
# Out:
# <AxesSubplot:xlabel='index'>

# %%
df.loc[61350:61500].plot(x='index', y =['engMdoPower_1_', 'engMdoPower_3_', 'thrusterAndPropulsion', 'battery_0__actualPower'])
# Out:
# <AxesSubplot:xlabel='index'>

# %%
df.loc[30000:50000].plot(x='index', y =['engMdoPower_1_', 'engMdoPower_3_', 'thrusterAndPropulsion', 'battery_0__actualPower'])
# Out:
# <AxesSubplot:xlabel='index'>
