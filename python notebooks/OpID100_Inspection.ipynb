# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df_full = pd.read_excel('data_full_sekres.xlsx')

# %%
df = df_full.loc[df_full['operationId'] == 100]
df0 = df.loc[df['dpMode'] == 0]
df1 = df.loc[df['dpMode'] == 1]
df2 = df.loc[df['dpMode'] == 2]


x = df['datetime']
y = df['sumEngMdoPower']
yy = df['thrusterAndPropulsion']

plt.plot(x,y)
plt.plot(x,yy)

# %%
y5 = df['battery_0__actualPower']

plt.plot(x,y5)

# %%
ynum = df['numberOfMdoEnginesRunning']
ydp = df['dpMode']

plt.plot(x,ynum)
plt.plot(x,ydp)

# %%
x = df['datetime']
y1 = df['thrusterAndPropulsion']
y2 = df['speedOverGround']
y3 = df['battery_0__actualPower']

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(x, y1, 'y')
ax1.plot(x,y2, 'm')
ax2.plot(x, y2, 'c')
ax2.grid()
ax1.set_xlabel('Time')
ax1.set_ylabel('Thruster (kW)')
ax2.set_ylabel('SOG')
ax1.set_title('Thruster and SOG')
# Out:
# Text(0.5, 1.0, 'Thruster and SOG')

# %%
# FIRST SPIKE 500 seconds
x = df.iloc[4000:4500]['datetime']
y1 = df.iloc[4000:4500]['thrusterAndPropulsion']
y2 = df.iloc[4000:4500]['engMdoPower_0_']
y3 = df.iloc[4000:4500]['engMdoPower_1_']
y4 = df.iloc[4000:4500]['engMdoPower_3_']
y5 = df.iloc[4000:4500]['battery_0__actualPower']

plt.plot(x,y1, color = 'y')
plt.plot(x,y2, color = 'r')
plt.plot(x,y3, color = 'g')
plt.plot(x,y4, color = 'b')
plt.plot(x,y5, color = 'm')

# %%
x = df.iloc[4000:4500]['datetime']
y1 = df.iloc[4000:4500]['thrusterAndPropulsion']
y2 = df.iloc[4000:4500]['speedOverGround']

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(x, y1, 'y')
ax2.plot(x, y2, 'b-')
ax2.grid()
ax1.set_xlabel('Time')
ax1.set_ylabel('Thruster (kW)')
ax2.set_ylabel('SOG')
ax1.set_title('First spike thruster and SOG')
# Out:
# Text(0.5, 1.0, 'First spike thruster and SOG')

# %%
x = df.iloc[4000:4500]['datetime']
y1 = df.iloc[4000:4500]['dpMode']

plt.plot(x,y1)

# %%
# Second Spike 45 seconds

x = df.iloc[24910:24955]['datetime']
y1 = df.iloc[24910:24955]['thrusterAndPropulsion']
y2 = df.iloc[24910:24955]['engMdoPower_0_']
y3 = df.iloc[24910:24955]['engMdoPower_1_']
y4 = df.iloc[24910:24955]['engMdoPower_3_']
y5 = df.iloc[24910:24955]['battery_0__actualPower']
y6 = df.iloc[24910:24955]['sumEngMdoPower']

plt.plot(x,y1, color = 'y')
plt.plot(x,y2, color = 'r')
plt.plot(x,y3, color = 'g')
plt.plot(x,y4, color = 'b')
plt.plot(x,y5, color = 'm')
plt.plot(x,y6, color = 'black')

# %%
x = df.iloc[24910:24955]['datetime']
y1 = df.iloc[24910:24955]['battery_0__actualPower']

plt.plot(x,y1)

# %%
x = df.iloc[24910:24955]['datetime']
y1 = df.iloc[24910:24955]['dpMode']

plt.plot(x,y1)

# %% [markdown]
# The behaviour of the battery makes no sense to me here.

# %%
# Highest Battery Spike

x = df.iloc[36590:36630]['datetime']
y1 = df.iloc[36590:36630]['thrusterAndPropulsion']
y2 = df.iloc[36590:36630]['engMdoPower_0_']
y3 = df.iloc[36590:36630]['engMdoPower_1_']
y4 = df.iloc[36590:36630]['engMdoPower_3_']
y5 = df.iloc[36590:36630]['battery_0__actualPower']
y6 = df.iloc[36590:36630]['sumEngMdoPower']

plt.plot(x,y1, color = 'y', label = 'Thruster')
plt.plot(x,y2, color = 'r')
plt.plot(x,y3, color = 'g')
plt.plot(x,y4, color = 'b')
plt.plot(x,y5, color = 'm', label = 'Battery')
plt.plot(x, y6, color = 'black', label = 'Sum Generators')
plt.title('60 second segment')
plt.xlabel('Time')
plt.ylabel('kW')
plt.legend()
plt.grid()

# %%
x = df.iloc[36590:36630]['datetime']
y1 = df.iloc[36590:36630]['dpMode']

plt.plot(x,y1)

# %% [markdown]
# It seems that the battery ramps up to avoid a third generator from starting up. I think the battery does this, then as soon as it is not needed for this reason it is charged back up to same SOC as before it did its job.

# %%
# The wierd little are with eng3 and propulsion
x = df.iloc[95378:96266]['datetime']
y1 = df.iloc[95378:96266]['thrusterAndPropulsion']
y2 = df.iloc[95378:96266]['engMdoPower_0_']
y3 = df.iloc[95378:96266]['engMdoPower_1_']
y4 = df.iloc[95378:96266]['engMdoPower_3_']
y5 = df.iloc[95378:96266]['battery_0__actualPower']
y6 = df.iloc[95378:96266]['sumEngMdoPower']

plt.plot(x,y1, color = 'y')
plt.plot(x,y2, color = 'r')
plt.plot(x,y3, color = 'g')
plt.plot(x,y4, color = 'b')
plt.plot(x,y5, color = 'm')
#plt.plot(x, y6, color = 'black')
plt.grid()

# %%
x = df.iloc[95378:96266]['datetime']
y1 = df.iloc[95378:96266]['dpMode']

plt.plot(x,y1)

# %% [markdown]
# These are three short periods in which the vessel is at dp maneuvering. We do not yet know what operation the vessel is in between these periods.

# %%
len(df)
# Out:
# 143453

# %%
# The last spike
x = df.iloc[142408:142953]['datetime']
y1 = df.iloc[142408:142953]['thrusterAndPropulsion']
y2 = df.iloc[142408:142953]['engMdoPower_0_']
y3 = df.iloc[142408:142953]['engMdoPower_1_']
y4 = df.iloc[142408:142953]['engMdoPower_3_']
y5 = df.iloc[142408:142953]['battery_0__actualPower']
y6 = df.iloc[142408:142953]['sumEngMdoPower']

plt.plot(x,y1, color = 'y')
plt.plot(x,y2, color = 'r')
plt.plot(x,y3, color = 'g')
plt.plot(x,y4, color = 'b')
plt.plot(x,y5, color = 'm')
#plt.plot(x, y6, color = 'black')
plt.grid()

# %%
x = df.iloc[142408:142953]['datetime']
y1 = df.iloc[142408:142953]['dpMode']
plt.plot(x,y1)
plt.ylabel('DP Mode')
# Out:
# Text(0, 0.5, 'DP Mode')

# %%
x = df.iloc[142408:142953]['datetime']
y1 = df.iloc[142408:142953]['numberOfMdoEnginesRunning']
plt.plot(x,y1)
plt.ylabel('No. of engines running')
# Out:
# Text(0, 0.5, 'No. of engines running')

# %%
#Last spike more zoom. Thrusters go brrrr

x = df.iloc[142430:142500]['datetime']
y1 = df.iloc[142430:142500]['thrusterAndPropulsion']
y2 = df.iloc[142430:142500]['engMdoPower_0_']
y3 = df.iloc[142430:142500]['engMdoPower_1_']
y4 = df.iloc[142430:142500]['engMdoPower_3_']
y5 = df.iloc[142430:142500]['battery_0__actualPower']
y6 = df.iloc[142430:142500]['sumEngMdoPower']

plt.plot(x,y1, color = 'y', label = 'Thruster')
plt.plot(x,y2, color = 'r')
plt.plot(x,y3, color = 'g')
plt.plot(x,y4, color = 'b')
plt.plot(x,y5, color = 'm', label = 'Battery')
#plt.plot(x, y6, color = 'black')
plt.title('70 second segment')
plt.grid()
plt.legend()

# %% [markdown]
# This is DP mode maneuvering. It seems that battery is used for peak shaving. I assume two engines are running due to redundancy.

# %%
# The area in the middle where it looks like theres lots of oscillations

x = df.iloc[85000:94500]['datetime']
y1 = df.iloc[85000:94500]['thrusterAndPropulsion']
y2 = df.iloc[85000:94500]['engMdoPower_0_']
y3 = df.iloc[85000:94500]['engMdoPower_1_']
y4 = df.iloc[85000:94500]['engMdoPower_3_']
y5 = df.iloc[85000:94500]['battery_0__actualPower']
y6 = df.iloc[85000:94500]['sumEngMdoPower']

plt.plot(x,y1, color = 'y')
plt.plot(x,y2, color = 'r')
plt.plot(x,y3, color = 'g')
plt.plot(x,y4, color = 'b')
plt.plot(x,y5, color = 'm')
#plt.plot(x, y6, color = 'black')
plt.grid()

# %%
x = df.iloc[85000:94500]['datetime']
y1 = df.iloc[85000:94500]['dpMode']
plt.plot(x,y1)
plt.ylabel('DP Mode')
# Out:
# Text(0, 0.5, 'DP Mode')

# %%
x = df.iloc[85000:94500]['datetime']
y1 = df.iloc[85000:94500]['numberOfMdoEnginesRunning']
plt.plot(x,y1)
plt.ylabel('No. of engines')
# Out:
# Text(0, 0.5, 'No. of engines')

# %%
# Now only the first couple of seconds of this interval (ONE MINUTE)

x = df.iloc[85000:85060]['datetime']
y1 = df.iloc[85000:85060]['thrusterAndPropulsion']
y2 = df.iloc[85000:85060]['engMdoPower_0_']
y3 = df.iloc[85000:85060]['engMdoPower_1_']
y4 = df.iloc[85000:85060]['engMdoPower_3_']
y5 = df.iloc[85000:85060]['battery_0__actualPower']
y6 = df.iloc[85000:85060]['sumEngMdoPower']

plt.plot(x,y1, color = 'y')
plt.plot(x,y2, color = 'r')
plt.plot(x,y3, color = 'g')
plt.plot(x,y4, color = 'b')
plt.plot(x,y5, color = 'm')
plt.grid()

# %%
plt.plot(x,y5, color = 'm')
plt.plot(x,y1, color = 'y')
plt.plot(x, y6, color = 'black')

# %% [markdown]
# I think this is a little strange. Two generators generate about the same as the demand, resulting in double generation. Also the battery looks like it is used for peak shaving even though the generators are running on super low efficiencies. Doesnt seem very good.

# %% [markdown]
# # Trying to figure out what dpMode = 0 is

# %%
x = df0['datetime']
y1 = df0['speedOverGround']

plt.plot(x,y1)

# %%
x = df0.iloc[44055:44075]['datetime']
y1 = df0.iloc[44055:44075]['speedOverGround']

plt.plot(x,y1)
plt.xlabel('Time')
plt.ylabel('SOG (kt)')
plt.title('20 second segment of SOG')
# Out:
# Text(0.5, 1.0, '20 second segment of SOG')

# %% [markdown]
# I find it strange that SOG could fluctuate this much for such a large vessel. This section is a total of 20 seconds. How tf can such a large vessel (many tons) go from 8.5 kt to 1.5 kt in a matter of seconds? i can't even do this with my 28 foot sailboat
