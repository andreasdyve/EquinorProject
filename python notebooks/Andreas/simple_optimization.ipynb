# %%
import pandas as pd
df = pd.read_excel('op5.xlsx')

# %%
df
# Out:
#        timeVectRelMinutes  battery_0__actualPower  thrusterAndPropulsion  \
# 0              903.833317                      12                   1056
# 1              903.850000                      20                   1056
# 2              903.866717                       6                   1056
# 3              903.883317                       6                   1056
# 4              903.899983                       7                   1034
# ...                   ...                     ...                    ...
# 12559         8522.956850                      37                    902
# 12560         8522.973517                      38                    946
# 12561         8522.990183                      38                    968
# 12562         8523.006850                      42                    946
# 12563         8523.023517                      30                    924
#
#        sumEngMdoPower  hotelLoad  shorePowerEstimated  \
# ...

# %%
import numpy as np
from  docplex.mp.model  import Model

m = Model()
n = 12564

load = df['thrusterAndPropulsion'].values
n1 = np.zeros(n)
n2 = np.zeros(n)

p1 = m.continuous_var_list(n)
p2 = m.continuous_var_list(n)

for i in range(n):
    #constraints
    m.add_constraint(p1[i] + p2[i] == load[i]) #kW, supply=demand 
    m.add_constraint(p1[i] <= 2100) #kW, rated cap
    m.add_constraint(p2[i] <= 2100) #kW, rated cap
    
    #efficiency calculations
    n1 = 0.4*p1[i]+0.21
    n2 = 0.4*p2[i]+0.21

n = n1 + n2

m.maximize(n)
sol = m.solve()
# Out:
# ---------------------------------------------------------------------------
# CplexSolverError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/docplex/mp/cplex_engine.py in solve(self, mdl, parameters, **kwargs)
#    1926             else:
# -> 1927                 cpx.solve()
#    1928
#
# ~/opt/anaconda3/lib/python3.8/site-packages/cplex/__init__.py in solve(self, paramsets)
#    1376         elif not self.objective.get_num_quadratic_nonzeros() > 0:
# -> 1377             _proc.lpopt(self._env._e, self._lp)
#    1378         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/cplex/_internal/_procedural.py in lpopt(env, lp)
#     765         status = CR.CPXXlpopt(env, lp)
# --> 766     check_status(env, status)
#     767
#
# ~/opt/anaconda3/lib/python3.8/site-packages/cplex/_internal/_procedural.py in __call__(self, env, status, from_cb)
#     248                     error_string = geterrorstring(env, status)
# ...
